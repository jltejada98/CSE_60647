# %% [markdown]
# # Assignment 1: Processing Data in Python (Instructor Solutions)
#
# Your assignment is the load the following CSV file into a pandas dataframe and answer the 3 questions below. Good luck!

# %%
import pandas as pd
input_name = 'https://raw.githubusercontent.com/cse44648/cse44648/master/datasets/hypothyroid.csv'

# this would be a good place to load the dataframe
df = pd.read_csv(input_name)

# %% [markdown]
# ## 1: Show, in a single table, the last ten instances (lines) of the dataframe. (10 pts)

# %%
df.tail(10)
# Out:
#        Age Sex On Thyroxine Query on Thyroxine On Antithyroid Medication  \
# 3153  78.0   F            f                  f                         f
# 3154  72.0   F            t                  f                         f
# 3155   NaN   F            f                  f                         f
# 3156  40.0   F            f                  f                         f
# 3157  69.0   F            f                  f                         f
# 3158  58.0   F            f                  f                         f
# 3159  29.0   F            f                  f                         f
# 3160  77.0   M            f                  f                         f
# 3161  74.0   F            f                  f                         f
# 3162  56.0   F            t                  f                         f
#
#      Thyroid Surgery Query Hypothyroid Query Hyperthyroid Pregnant Sick  ...  \
# 3153               f                 f                  t        f    f  ...
# ...

# %% [markdown]
# ## 2: Show, in a single table, only the age, sex, and class features (columns) of the first five instances. (10 pts)

# %%
# simplest solution
df[['Age','Sex','Class']].head()
# Out:
#     Age Sex        Class
# 0  72.0   M  hypothyroid
# 1  15.0   F  hypothyroid
# 2  24.0   M  hypothyroid
# 3  24.0   F  hypothyroid
# 4  77.0   M  hypothyroid

# %% [markdown]
# ## 3: Show, in a single table, all the instances (and all features for those instances) that have age between 18 and 24, inclusive. (15 pts)

# %%
# simplest solution
#f[(df['Age'] >= 18) & (df['Age'] <= 24)]

# can also explicitly use .loc:
df.loc[(df['Age'] >= 18) & (df['Age'] <= 24)]
# Out:
#        Age Sex On Thyroxine Query on Thyroxine On Antithyroid Medication  \
# 2     24.0   M            f                  f                         f
# 3     24.0   F            f                  f                         f
# 8     20.0   F            f                  f                         f
# 34    24.0   F            f                  f                         f
# 95    22.0   F            f                  f                         f
# ...    ...  ..          ...                ...                       ...
# 2998  21.0   F            f                  f                         f
# 3029  19.0   F            f                  f                         f
# 3085  19.0   F            f                  f                         f
# 3112  24.0   F            f                  f                         f
# 3135  23.0   F            t                  f                         f
#
#      Thyroid Surgery Query Hypothyroid Query Hyperthyroid Pregnant Sick  ...  \
# ...
