# %% [markdown]
# # Clustering

# %% [markdown]
# Clustering is the unsupervised learning task of grouping object  based on given real and/or categorical input ("feature") data, _X_. The objective of clustering is to learn groupings such that objects in the same group (called a cluster) are more similar to each other than to those in other groups (clusters).
#
# A variety of clustering algorithms exist. These algorithms can assign clusters to points based on different properties, including distance connectivity, centroid distance, distributional similarity, relative density, and graph connectivity.
#
# Here, we'll use the scikit-learn (sklearn) package to expore the use of several clustering algorithms. Let's fetch the Iris dataset from the UCI Machine Learning repository.

# %% [markdown]
# <span style="color:red">A modification to the original Notebook.</span>
# Note: the code below did not work for me. Apparently, my seaborn library is not installing correctly. If you have the same problem, use the snipped below.

# %%
# %matplotlib inline
#%matplotlib notebook
# uncomment matplotlib notebook (and restart kernel) to add rotation options to 3D figures
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
#matplotlib.style.use('seaborn-notebook')
#matplotlib.rcParams["patch.force_edgecolor"] = True
available_styles = plt.style.available
#print(available_styles)

style = 'seaborn-notebook' if 'seaborn-notebook' in available_styles else 'seaborn-v0_8'
#print(f"Using style: {style}")
matplotlib.style.use(style)
matplotlib.rcParams["patch.force_edgecolor"] = True

# %% [markdown]
# <span style="color:red">A modification to the original Notebook.</span>
# If the code did not work for you, replace with this snippet:

# %%
# %matplotlib inline
#%matplotlib notebook
# uncomment matplotlib notebook (and restart kernel) to add rotation options to 3D figures
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
available_styles = plt.style.available

#Uncomment the code below to see which seaborn style you want to use
#print(available_styles)
#Replace the 'seaborn-v0_8' with the style of your choice from the list above
style = 'seaborn-notebook' if 'seaborn-notebook' in available_styles else 'seaborn-v0_8'
matplotlib.style.use(style)
matplotlib.rcParams["patch.force_edgecolor"] = True

# %% [markdown]
# ## *k*-Means Clustering

# %% [markdown]
# Let's begin by loading some basic packages and the Iris dataset, a well-known multivariate dataset with four features describing three classes of flowers.

# %%
import numpy as np
import pandas as pd

fileURL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
data = pd.read_csv(fileURL, names=['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width', 'Name'], header=None)

X = data.iloc[:, :-1]  # features
y = data.iloc[:, -1]  # class

print(X.head())
print()
print(y.head())
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
#
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Name, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y)
y = le.transform(y)

# %% [markdown]
# Let's use k-means clustering to cluster the Iris Flower database. To determine the clusters, the algorithm will only use the feature data, `X`. We can use the class values, `y`, as ground truth to assess the "goodness" of the generated clusters. We'll use several values of _k_ and observe the different clusters they produce.

# %%
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans

# Define a set of k-means estimators.
estimators = {'k-Means (k=2)': KMeans(n_clusters=2),
              'k-Means (k=3)': KMeans(n_clusters=3),
              'k-Means (k=4)': KMeans(n_clusters=4),
              'k-Means (k=5)': KMeans(n_clusters=5)}

# Define a matplotlib figure.
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

fignum = 1
for name, est in estimators.items():
    ax = plt.subplot(2, 2, fignum, projection='3d', elev=48, azim=134)

    # Fit the estimator.
    est.fit(X)
    labels = est.labels_

    # Define a scatterplot.
    ax.scatter(X.iloc[:, 3], X.iloc[:, 0], X.iloc[:, 2], c=labels.astype(float))

    # Customize the plot.
    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_xlabel('Petal width')
    ax.set_ylabel('Sepal length')
    ax.set_zlabel('Petal length')
    plt.title("\n" + name + "\n")
    fignum = fignum + 1
# Out:
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:16: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(2, 2, fignum, projection='3d', elev=48, azim=134)
# /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:26: MatplotlibDeprecationWarning: The w_xaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use xaxis instead.
#   ax.w_xaxis.set_ticklabels([])
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:27: MatplotlibDeprecationWarning: The w_yaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use yaxis instead.
#   ax.w_yaxis.set_ticklabels([])
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:28: MatplotlibDeprecationWarning: The w_zaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use zaxis instead.
#   ax.w_zaxis.set_ticklabels([])
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:16: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(2, 2, fignum, projection='3d', elev=48, azim=134)
# /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:26: MatplotlibDeprecationWarning: The w_xaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use xaxis instead.
#   ax.w_xaxis.set_ticklabels([])
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:27: MatplotlibDeprecationWarning: The w_yaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use yaxis instead.
#   ax.w_yaxis.set_ticklabels([])
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:28: MatplotlibDeprecationWarning: The w_zaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use zaxis instead.
#   ax.w_zaxis.set_ticklabels([])
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:16: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(2, 2, fignum, projection='3d', elev=48, azim=134)
# /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:26: MatplotlibDeprecationWarning: The w_xaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use xaxis instead.
#   ax.w_xaxis.set_ticklabels([])
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:27: MatplotlibDeprecationWarning: The w_yaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use yaxis instead.
#   ax.w_yaxis.set_ticklabels([])
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:28: MatplotlibDeprecationWarning: The w_zaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use zaxis instead.
#   ax.w_zaxis.set_ticklabels([])
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:16: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(2, 2, fignum, projection='3d', elev=48, azim=134)
# /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:26: MatplotlibDeprecationWarning: The w_xaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use xaxis instead.
#   ax.w_xaxis.set_ticklabels([])
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:27: MatplotlibDeprecationWarning: The w_yaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use yaxis instead.
#   ax.w_yaxis.set_ticklabels([])
# /var/folders/0_/rvb2llf93dbdq2r_5rn3r2hr0000gn/T/ipykernel_63957/2178691107.py:28: MatplotlibDeprecationWarning: The w_zaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use zaxis instead.
#   ax.w_zaxis.set_ticklabels([])

# %% [markdown]
# <span style="color:red">A modification to the original Notebook.</span>
# The code above runs, but with an error. Use the code below to fix the problem.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans

# Define your data here. For example, using the Iris dataset:
from sklearn.datasets import load_iris
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)

# Define a set of k-means estimators.
estimators = {'k-Means (k=2)': KMeans(n_clusters=2),
              'k-Means (k=3)': KMeans(n_clusters=3),
              'k-Means (k=4)': KMeans(n_clusters=4),
              'k-Means (k=5)': KMeans(n_clusters=5)}

# Define a matplotlib figure.
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8), subplot_kw={'projection': '3d'})

fignum = 0
for name, est in estimators.items():
    ax = axes[fignum // 2, fignum % 2]

    # Fit the estimator.
    est.fit(X)
    labels = est.labels_

    # Define a scatterplot.
    scatter = ax.scatter(X.iloc[:, 3], X.iloc[:, 0], X.iloc[:, 2], c=labels.astype(float), cmap=ListedColormap(['r', 'g', 'b', 'y']))

    # Customize the plot.
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_zticks([])
    ax.set_xlabel('Petal width')
    ax.set_ylabel('Sepal length')
    ax.set_zlabel('Petal length')
    ax.set_title(name)
    fignum += 1

plt.tight_layout()
plt.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# <span style="color:red">A modification to the original Notebook.</span>
# Note: the code below did not work for me. Apparently, my seaborn library is not installing correctly. If you have the same problem, use the snipped below.

# %%
# Plot the ground truth.
fig = plt.figure(fignum, figsize=(10, 8))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

for name, label in [('Setosa', 0),
                    ('Versicolour', 1),
                    ('Virginica', 2)]:
    ax.text3D(X.loc[y == label, 'Petal Width'].mean(),
              X.loc[y == label, 'Sepal Length'].mean() + 1.5,
              X.loc[y == label, 'Petal Length'].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))

# Reorder the labels to have colors matching the cluster results.
y_c = np.choose(y, [1, 2, 0]).astype(float)
ax.scatter(X.iloc[:, 3], X.iloc[:, 0], X.iloc[:, 2], c=y_c)

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_xlabel('Petal width')
ax.set_ylabel('Sepal length')
ax.set_zlabel('Petal length')
plt.title("\nActual Classes\n")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Petal Width'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 8
#       3 ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
#       5 for name, label in [('Setosa', 0),
#       6                     ('Versicolour', 1),
#       7                     ('Virginica', 2)]:
# ----> 8     ax.text3D(X.loc[y == label, 'Petal Width'].mean(),
#       9               X.loc[y == label, 'Sepal Length'].mean() + 1.5,
#      10               X.loc[y == label, 'Petal Length'].mean(), name,
#      11               horizontalalignment='center',
#      12               bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
#      14 # Reorder the labels to have colors matching the cluster results.
#      15 y_c = np.choose(y, [1, 2, 0]).astype(float)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/pandas/core/indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/pandas/core/indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
#    1283 tup = self._validate_tuple_indexer(tup)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/pandas/core/indexing.py:1000, in _LocationIndexer._getitem_lowerdim(self, tup)
#     996 for i, key in enumerate(tup):
#     997     if is_label_like(key):
#     998         # We don't need to check for tuples here because those are
#     999         #  caught by the _is_nested_tuple_indexer check above.
# -> 1000         section = self._getitem_axis(key, axis=i)
#    1002         # We should never have a scalar section here, because
#    1003         #  _getitem_lowerdim is only called after a check for
#    1004         #  is_scalar_access, which that would be.
#    1005         if section.ndim == self.ndim:
#    1006             # we're in the middle of slicing through a MultiIndex
#    1007             # revise the key wrt to `section` by inserting an _NS
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/pandas/core/indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/pandas/core/indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/pandas/core/generic.py:4082, in NDFrame.xs(self, key, axis, level, drop_level)
#    4080 if axis == 1:
#    4081     if drop_level:
# -> 4082         return self[key]
#    4083     index = self.columns
#    4084 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CSE_60647/lib/python3.8/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Petal Width'

# %% [markdown]
# <span style="color:red">A modification to the original Notebook.</span>
# Use this code instead.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_iris

# Load Iris dataset
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = iris.target

# Create the 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_axes([0, 0, .95, 1], projection='3d')
ax.view_init(elev=48, azim=134)

# Add text labels for the clusters
for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X.loc[y == label, 'petal width (cm)'].mean(),
              X.loc[y == label, 'sepal length (cm)'].mean() + 1.5,
              X.loc[y == label, 'petal length (cm)'].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))

# Reorder the labels to have colors matching the cluster results.
y_c = np.choose(y, [1, 2, 0]).astype(float)

# Define a colormap
cmap = plt.get_cmap('viridis')

# Create the scatter plot
scatter = ax.scatter(X['petal width (cm)'], X['sepal length (cm)'], X['petal length (cm)'], c=y_c, cmap=cmap, edgecolor='k', s=50)

# Customize the plot
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
ax.set_xlabel('Petal width')
ax.set_ylabel('Sepal length')
ax.set_zlabel('Petal length')
plt.title("\nActual Classes\n")
plt.show()

# %% [markdown]
# We can see that when _k_ = 3, there is a high degree of correspondence between the clusters and the actual class values.

# %% [markdown]
# ### Digits

# %% [markdown]
# Now let's load the Digits dataset, a well-known dataset that is composed of handwritten digits between 0 and 9 stretched into a rectangular 16x16 box. Each instance in the dataset has 64 features, representing the individual pixels that comprise the image of a digit.

# %%
train = 'https://archive.ics.uci.edu/ml/machine-learning-databases/optdigits/optdigits.tra'
test = 'https://archive.ics.uci.edu/ml/machine-learning-databases/optdigits/optdigits.tes'

# Make the digits dataset.
df_train = pd.read_csv(train, header=None)
df_test = pd.read_csv(test, header=None)
df = pd.concat([df_train, df_test], axis=0)
df = df.rename(columns={64: 'Class'})

X = df.iloc[:, :-1]
y = df.iloc[:, -1]

print(X.head())
print()
print(y.head())

# %% [markdown]
# To help visualize the digits data, we can use PCA to perform dimensionality reduction to reduce the digits dataset from 64 features (dimensions) to 2.

# %%
X.shape

# %%
from sklearn.decomposition import PCA

# Perform PCA dimensionality reduction.
pca = PCA(n_components=2, svd_solver='randomized').fit(X)
X = pca.transform(X)

# %% [markdown]
# Now we can cluster the digits in these two dimensions. Again, we can use _k_-means clustering.

# %%
from scipy.cluster.vq import kmeans
from scipy.spatial.distance import cdist, pdist

# Cluster data into k=1..20 clusters.
k_max = 20
k_range = range(1, k_max+1)

k_means = [kmeans(X, k) for k in k_range]
centroids = [cent for (cent, var) in k_means]
D_k = [cdist(X, cent, 'euclidean') for cent in centroids]
c_idx = [np.argmin(D, axis=1) for D in D_k]
dist = [np.min(D, axis=1) for D in D_k]

# Cluster evaluation
tot_withinss = [sum(d**2) for d in dist]  # total within-cluster sum of squares
totss = sum(pdist(X)**2) / X.shape[0]  # total sum of squares
betweenss = totss - tot_withinss  # between-cluster sum of squares
print(tot_withinss)
print(totss)
print(betweenss)

# %% [markdown]
# We can sweep over a range of k values (here, from 1 to 20) to identify the "elbow" point. The point where k = 10 is denoted as the elbow point via a red circle in this plot. As there are ten digits in the dataset, the optimal value of *k*-means should ideally be ten.

# %%
# Plots.
k_idx = 9 # k=10 note: k_idx is index, not the number of clusters (k), so k_idx = k - 1

# Elbow curve.
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(k_range, betweenss / totss * 100, 'b*-')
ax.plot(k_range[k_idx], betweenss[k_idx] / totss * 100, marker='o', markersize=12, 
    markeredgewidth=2, markeredgecolor='r', markerfacecolor='None')

ax.set_ylim((0,100))
plt.grid(True)

plt.xlabel('Number of Clusters')
plt.ylabel('Variance Explained (%)')
plt.title('Elbow for k-Means Clustering')

# %% [markdown]
# With _k_ = 10 we can extract the particular points that represent the cluster centroids. As we are defining ten clusters, there are ten cluster centroids, one corresponding to each cluster.

# %%
centroids[10]

# %%
# Show centroids for k=10 clusters.
plt.figure()
for i in range(k_idx + 1):
    img = pca.inverse_transform(centroids[k_idx][i]).reshape(8, 8)
    ax = plt.subplot(3, 4, i+1)
    ax.set_xticks([])
    ax.set_yticks([])
    plt.imshow(img, cmap=cm.gray)
    plt.title('Cluster %d' % i)

# %% [markdown]
# Each of the centroids represents a digit. Can you tell which cluster corresponds to each digit?
#
# You may want to start with the simplest digits, like 1 and 7, and use process of elimination. How could you check your labels?
#
# How well do you think these clusters would work to classify unknown digits?

# %%
# Show centroids for k clusters, where k varies.
for k in range(k_idx+1):
    plt.figure()
    for i in range(k + 1):
        img = pca.inverse_transform(centroids[k][i]).reshape(8, 8)
        ax = plt.subplot(4, 4, i+1)
        ax.set_xticks([])
        ax.set_yticks([])
        plt.imshow(img, cmap=cm.gray)
        plt.title('Cluster %d' % i)

# %% [markdown]
# Finally, we can compare the clusters produced by _k_-means with ten clusters to the actual classes of the digits.

# %%
clr = cm.nipy_spectral(np.linspace(0, 1, 10)).tolist()

# Compare k=10 clustering vs. actual digits (PCA projections).
fig = plt.figure(figsize=(14, 5))
ax = fig.add_subplot(121)

for i in range(10):
    ind = (y == i)
    ind = np.array(ind, dtype=bool)  # needed for some versions of packages
    ax.scatter(X[ind, 0], X[ind, 1], s=35, c=clr[i], label='%d'%i, edgecolor='k')
    plt.legend()

plt.title('Actual Digits')
ax = fig.add_subplot(122)

for i in range(k_idx+1):
    ind = (c_idx[k_idx]==i)
    ax.scatter(X[ind, 0], X[ind, 1], s=35, c=clr[i], label='C%d'%i, edgecolor='k')

plt.legend()
plt.title('k=%d clusters' % k_range[k_idx])

plt.show()

# %% [markdown]
# ## Hierarchical Clustering

# %% [markdown]
# Hierarchical clustering is a method of cluster analysis that builds a hierarchy of clusters. In agglomerative clustering, each instance starts in its own cluster, with pairs of clusters merged based upon their distance as one moves up the hierarchy. The linkage criterion determines the distance between sets of observations as a function of the pairwise distances between observations.
#
# Here we illustrate the various linkage options for agglomerative clustering on a 2D embedding of the digits dataset. The goal of this example is to show intuitively how the metrics behave, and not to find good clusters for the digits. This is why the example works on a 2D embedding.

# %%
from scipy import ndimage
from sklearn import datasets, manifold
from sklearn.cluster import AgglomerativeClustering

digits = datasets.load_digits(n_class=10)
X = digits.data
y = digits.target
n_samples, n_features = X.shape

np.random.seed(0)

def nudge_images(X, y):
    # Having a larger dataset shows more clearly the behavior of the
    # methods, but we multiply the size of the dataset only by 2, as the
    # cost of the hierarchical clustering methods are strongly
    # super-linear in n_samples.
    shift = lambda x: ndimage.shift(x.reshape((8, 8)),
                                  .3 * np.random.normal(size=2),
                                  mode='constant',
                                  ).ravel()
    X = np.concatenate([X, np.apply_along_axis(shift, 1, X)])
    Y = np.concatenate([y, y], axis=0)
    return X, Y

X, y = nudge_images(X, y)

# Visualize the clustering.
def plot_clustering(X_red, X, labels, title=None):
    x_min, x_max = np.min(X_red, axis=0), np.max(X_red, axis=0)
    X_red = (X_red - x_min) / (x_max - x_min)

    plt.figure(figsize=(6, 4))
    for i in range(X_red.shape[0]):
        plt.text(X_red[i, 0], X_red[i, 1], str(y[i]),
                 color=plt.cm.nipy_spectral(labels[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    plt.xticks([])
    plt.yticks([])
    if title is not None:
        plt.title(title, size=17)
    plt.axis('off')
    plt.tight_layout()

# 2D embedding of the digits dataset.
X_red = manifold.SpectralEmbedding(n_components=2).fit_transform(X)

for linkage in ('ward', 'average', 'complete'):
    clustering = AgglomerativeClustering(linkage=linkage, n_clusters=10)
    clustering.fit(X_red)
    plot_clustering(X_red, X, clustering.labels_, "%s linkage" % linkage)

plt.show()

# %% [markdown]
# We can see that agglomerative clustering tends to create uneven cluster sizes. This behavior is especially pronounced for the average linkage strategy, that ends up with a couple of singleton clusters.

# %% [markdown]
# We can look at the relationships between the clusters using a dendogram. Its much easier to look at the dendogram in scipy version of agglomerative clustering than the scikit-learn function.

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# generate the linkage matrix
Z = linkage(X, 'ward')

plt.title('Hierarchical Clustering Dendrogram (truncated)')
plt.xlabel('sample index or (cluster size)')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=10,  # show only the last p merged clusters
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.show()

# %% [markdown]
# Because we are working with only two components of image data, the clusters may not be very good. How could you evaluate that?

# %% [markdown]
# Try clustering the iris data using agglomerative clustering.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering

# Load Iris dataset
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = iris.target

# Perform Agglomerative Clustering
agg_clustering = AgglomerativeClustering(n_clusters=3)
agg_labels = agg_clustering.fit_predict(X)

# Create the 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_axes([0, 0, .95, 1], projection='3d')
ax.view_init(elev=48, azim=134)

# Add text labels for the clusters
for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X.loc[y == label, 'petal width (cm)'].mean(),
              X.loc[y == label, 'sepal length (cm)'].mean() + 1.5,
              X.loc[y == label, 'petal length (cm)'].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))

# Define a colormap
cmap = plt.get_cmap('viridis')

# Create the scatter plot
scatter = ax.scatter(X['petal width (cm)'], X['sepal length (cm)'], X['petal length (cm)'], c=agg_labels, cmap=cmap, edgecolor='k', s=50)

# Customize the plot
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
ax.set_xlabel('Petal width')
ax.set_ylabel('Sepal length')
ax.set_zlabel('Petal length')
plt.title("\nAgglomerative Clustering\n")
plt.show()
